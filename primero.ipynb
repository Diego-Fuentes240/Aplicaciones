# %%
from pint import UnitRegistry 

ureg = UnitRegistry()

meter = ureg.meter
second = ureg.second

a = 9.8 * meter / second**2

print(a)
# Out:
# 9.8 meter / second ** 2

# %%
from modsim import * 

bikershare = State(Ollin = 10, W = 2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 from modsim import *
#       2
# ----> 3 bikershare = State(Ollin = 10, W = 2)
#
# NameError: name 'State' is not defined
